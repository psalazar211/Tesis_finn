# %% [markdown]
# # FINN - Functional Verification of End-to-End Flow
# -----------------------------------------------------------------
#
# **Important: This notebook depends on the [tfc_end2end_example](tfc_end2end_example.ipynb) notebook, because we are using models that are available at intermediate steps in the end-to-end flow. So please make sure the needed .onnx files are generated to run this notebook.**
#
# In this notebook, we will show how to take the intermediate results of the end-to-end tfc example and verify their functionality with different methods. In the following picture you can see the section in the end-to-end flow about the *Simulation & Emulation Flows*.

# %% [markdown]
# <img src="verification.svg" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# We will use the following helper functions, `showSrc` to show source code of FINN library calls and `showInNetron` to show the ONNX model at the current transformation step. The Netron displays are interactive, but they only work when running the notebook actively and not on GitHub (i.e. if you are viewing this on GitHub you'll only see blank squares).

# %%
from finn.util.basic import make_build_dir
from finn.util.visualization import showSrc, showInNetron
import os

build_dir = os.environ["FINN_BUILD_DIR"]

# %% [markdown]
# To verify the simulations, a "golden" output is calculated as a reference. This is calculated directly from the Brevitas model using PyTorch, by running some example data from the MNIST dataset through the trained model.

# %%
from pkgutil import get_data
import onnx
import onnx.numpy_helper as nph
import torch
from finn.util.test import get_test_model_trained

fc = get_test_model_trained("TFC", 1, 1)
raw_i = get_data("qonnx.data", "onnx/mnist-conv/test_data_set_0/input_0.pb")
input_tensor = onnx.load_tensor_from_string(raw_i)
input_brevitas = torch.from_numpy(nph.to_array(input_tensor).copy()).float()
output_golden = fc.forward(input_brevitas).detach().numpy()
output_golden
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1255: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at ../c10/core/TensorImpl.h:1758.)
#   return super(Tensor, self).rename(names)
# array([[-1.4090618, -1.3267527,  0.9779036, -1.2444434, -1.4090618,
#         -1.6559892, -1.3267527, -1.4913709, -1.3267527, -1.6559892]],
#       dtype=float32)

# %% [markdown]
# ## Simulation using Python <a id='simpy'></a>
#
# If an ONNX model consists of [standard ONNX](https://github.com/onnx/onnx/blob/main/docs/Operators.md) nodes and/or FINN custom operations that do not belong to the fpgadataflow (`backend` $\neq$ `fpgadataflow.hls` or `backend` $\neq$ `fpgadataflow.rtl`) this model can be checked for functionality using Python.
#
# To simulate a standard ONNX node [onnxruntime](https://github.com/microsoft/onnxruntime) is used. onnxruntime is an open source tool developed by Microsoft to run standard ONNX nodes. For the FINN custom op nodes execution, functions are defined. The following is an example of the execution function of an XNOR popcount node.

# %%
from qonnx.custom_op.general.xnorpopcount import xnorpopcountmatmul
showSrc(xnorpopcountmatmul)
# Out:
# def xnorpopcountmatmul(inp0, inp1):
#     """Simulates XNOR-popcount matrix multiplication as a regular bipolar
#     matrix multiplication followed by some post processing."""
#     # extract the operand shapes
#     # (M, K0) = inp0.shape
#     # (K1, N) = inp1.shape
#     K0 = inp0.shape[-1]
#     K1 = inp1.shape[0]
#     # make sure shapes are compatible with matmul
#     assert K0 == K1, "Matrix shapes are not compatible with matmul."
#     K = K0
#     # convert binary inputs to bipolar
#     inp0_bipolar = 2.0 * inp0 - 1.0
#     inp1_bipolar = 2.0 * inp1 - 1.0
#     # call regular numpy matrix multiplication
#     out = np.matmul(inp0_bipolar, inp1_bipolar)
#     # XNOR-popcount does not produce the regular dot product result --
#     # it returns the number of +1s after XNOR. let P be the number of +1s
#     # and N be the number of -1s. XNOR-popcount returns P, whereas the
#     # regular dot product result from numpy is P-N, so we need to apply
#     # some correction.
#     # out = P-N
#     # K = P+N
#     # out + K = 2P, so P = (out + K)/2
#     return (out + K) * 0.5

# %% [markdown]
# The function contains a description of the behaviour in Python and can thus calculate the result of the node.
#
# This execution function and onnxruntime is used when `execute_onnx` from `onnx_exec` is applied to the model. The model is then simulated node by node and the result is stored in a context dictionary, which contains the values of each tensor at the end of the execution. To get the result, only the output tensor has to be extracted.
#
# The procedure is shown below. We take the model right before the nodes should be converted into HW layers and generate an input tensor to pass to the execution function. The input tensor is generated from the Brevitas example inputs.

# %%
import numpy as np
from qonnx.core.modelwrapper import ModelWrapper
input_dict = {"global_in": nph.to_array(input_tensor)}

model_for_sim = ModelWrapper(build_dir+"/tfc_w1a1_ready_for_hw_conversion.onnx")

# %%
import finn.core.onnx_exec as oxe
output_dict = oxe.execute_onnx(model_for_sim, input_dict, return_full_exec_context=False)
output_pysim = output_dict[list(output_dict.keys())[0]]

try:
    assert np.isclose(output_pysim, np.where(output_golden[0]==np.amax(output_golden[0])), atol=1e-3).all()
    print("Results are the same!")
except AssertionError:
    assert False, "The results are not the same!"
# Out:
# Results are the same!

# %% [markdown]
# The result is compared with the theoretical "golden" value for verification.

# %% [markdown]
# ## Simulation (cppsim) using C++
#
# When dealing with HLS or RTL custom op nodes in FINN the simulation using Python is no longer sufficient. If the nodes are specialized to HLS layers, the simulation using C++ can be used. To do this, the input tensor is stored in a .npy file and C++ code is generated that reads the values from the .npy array, streams them to the corresponding `finn-hlslib` function and writes the result to a new .npy file. This in turn can be read in Python and processed in the FINN flow. For this example the model after setting the folding factors in the HLS variants of the layers, please be aware that this is not the full model, but the dataflow partition, so before executing at the end of this section we have to integrate the model back into the parent model.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Note: HW layer can also be converted to RTL variants, in this case "cppsim" is not an option we can execute. If nevertheless "cppsim" is selected as execution mode for the layer, the execution defaults to the parent class. Like this, networks with a mix of HLS and RTL layers can be executed using "cppsim" for the HLS layers.</b>
# </div>

# %%
model_for_cppsim = ModelWrapper(build_dir+"/tfc_w1_a1_set_folding_factors.onnx")

# %% [markdown]
# To generate the code for this simulation and to generate the executable two transformations are used:
# * `PrepareCppSim` which generates the C++ code for the corresponding HLS layer
# * `CompileCppSim` which compules the C++ code and stores the path to the executable

# %%
from finn.transformation.fpgadataflow.prepare_cppsim import PrepareCppSim
from finn.transformation.fpgadataflow.compile_cppsim import CompileCppSim
from qonnx.transformation.general import GiveUniqueNodeNames

model_for_cppsim = model_for_cppsim.transform(GiveUniqueNodeNames())
model_for_cppsim = model_for_cppsim.transform(PrepareCppSim())
model_for_cppsim = model_for_cppsim.transform(CompileCppSim())

# %% [markdown]
# When we take a look at the model using netron, we can see that the transformations introduced new attributes.

# %%
model_for_cppsim.save(build_dir+"/tfc_w1_a1_for_cppsim.onnx")
#showInNetron(build_dir+"/tfc_w1_a1_for_cppsim.onnx")

# %% [markdown]
# The following node attributes have been added:
# * `code_gen_dir_cppsim` indicates the directory where the files for the simulation using C++ are stored
# * `executable_path` specifies the path to the executable
#
# We take now a closer look into the files that were generated:

# %%
from qonnx.custom_op.registry import getCustomOp

fc0 = model_for_cppsim.graph.node[1]
fc0w = getCustomOp(fc0)
code_gen_dir = fc0w.get_nodeattr("code_gen_dir_cppsim")
# !ls {code_gen_dir}
# Out:
# compile.sh	      memblock.dat  thresh.h
# execute_MVAU_hls.cpp  node_model    weights.npy

# %% [markdown]
# Besides the .cpp file, the folder contains .h files with the weights and thresholds. The shell script contains the compile command and *node_model* is the executable generated by compilation. Comparing this with the `executable_path` node attribute, it can be seen that it specifies exactly the path to *node_model*.

# %% [markdown]
# To simulate the model the execution mode(exec_mode) must be set to "cppsim". This is done using the transformation SetExecMode.

# %%
from finn.transformation.fpgadataflow.set_exec_mode import SetExecMode

model_for_cppsim = model_for_cppsim.transform(SetExecMode("cppsim"))
model_for_cppsim.save(build_dir+"/tfc_w1_a1_for_cppsim.onnx")

# %% [markdown]
# Before the model can be executed using `execute_onnx`, we integrate the child model in the parent model. The function reads then the `exec_mode` and writes the input into the correct directory in a .npy file. To be able to read this in C++, there is an additional .hpp file ([npy2apintstream.hpp](https://github.com/Xilinx/finn/blob/main/src/finn/qnn-data/cpp/npy2apintstream.hpp)) in FINN, which uses cnpy to read .npy files and convert them into streams, or to read a stream and write it into an .npy. [cnpy](https://github.com/rogersce/cnpy) is a helper to read and write .npy and .npz formates in C++.
#
# The result is again compared to the "golden" output.

# %%
parent_model = ModelWrapper(build_dir+"/tfc_w1_a1_dataflow_parent.onnx")
sdp_node = parent_model.graph.node[1]
child_model = build_dir + "/tfc_w1_a1_for_cppsim.onnx"
getCustomOp(sdp_node).set_nodeattr("model", child_model)
output_dict = oxe.execute_onnx(parent_model, input_dict)
output_cppsim = output_dict[list(output_dict.keys())[0]]

try:
    assert np.isclose(output_cppsim, np.where(output_golden[0]==np.amax(output_golden[0])), atol=1e-3).all()
    print("Results are the same!")
except AssertionError:
    assert False, "The results are not the same!"
# Out:
# Results are the same!

# %% [markdown]
# ## Emulation (rtlsim) using PyVerilator
#
# The emulation using [PyVerilator](https://github.com/maltanar/pyverilator) can be done after IP blocks are generated from the corresponding HLS layers or for RTL layers directly using the generated Verilog files. Pyverilator is a tool which makes it possible to simulate verilog files using verilator via a python interface.
#
# We have two ways to use rtlsim, one is to run the model node-by-node as with the simulation methods, but if the model is in the form of the dataflow partition, the part of the graph that consist of only HLS/RTL nodes could also be executed as whole.

# %% [markdown]
# Because at the point where we want to grab and verify the model, the model is already in split form (parent graph consisting of non-hls layers and child graph consisting only of hls layers) we first have to reference the child graph within the parent graph. This is done using the node attribute `model` for the `StreamingDataflowPartition` node.
#
# First the procedure is shown, if the child graph has ip blocks corresponding to the individual layers, then the procedure is shown, if the child graph already has a stitched IP.

# %% [markdown]
# ### Emulation of model node-by-node
#
# The child model is loaded and the `exec_mode` for each node is set. To prepare the node-by-node emulation the transformation `PrepareRTLSim` is applied to the child model. With this transformation the emulation files are created for each node and can be used directly when calling `execute_onnx()`. Each node has a new node attribute "rtlsim_so" after transformation, which contains the path to the corresponding emulation files. Then it is saved in a new .onnx file so that the changed model can be referenced in the parent model.

# %%
from finn.transformation.fpgadataflow.prepare_rtlsim import PrepareRTLSim
from finn.transformation.fpgadataflow.prepare_ip import PrepareIP
from finn.transformation.fpgadataflow.hlssynth_ip import HLSSynthIP

test_fpga_part = "xc7z020clg400-1"
target_clk_ns = 10

child_model = ModelWrapper(build_dir + "/tfc_w1_a1_set_folding_factors.onnx")
child_model = child_model.transform(GiveUniqueNodeNames())
child_model = child_model.transform(PrepareIP(test_fpga_part, target_clk_ns))
child_model = child_model.transform(HLSSynthIP())
child_model = child_model.transform(SetExecMode("rtlsim"))
child_model = child_model.transform(PrepareRTLSim())
child_model.save(build_dir + "/tfc_w1_a1_dataflow_child.onnx")
# Out:
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_LabelSelect_hls_0_ctagf3yp/LabelSelect_hls_0.v:854:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                   : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45.flow_control_loop_pipe_sequential_init_U
#   854 | #0 ap_loop_init_int = 1'b1;
#       |  ^
#                   ... For warning description see https://verilator.org/warn/STMTDLY?v=4.224
#                   ... Use "/* verilator lint_off STMTDLY */" and lint_on around source to disable this message.
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_LabelSelect_hls_0_ctagf3yp/LabelSelect_hls_0.v:855:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                   : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45.flow_control_loop_pipe_sequential_init_U
#   855 | #0 ap_done_cache = 1'b0;
#       |  ^
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_LabelSelect_hls_0_ctagf3yp/LabelSelect_hls_0.v:606:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                   : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45
#   606 | #0 ap_CS_fsm = 1'd1;
#       |  ^
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_LabelSelect_hls_0_ctagf3yp/LabelSelect_hls_0.v:607:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                   : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45
#   607 | #0 ap_done_reg = 1'b0;
#       |  ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_LabelSelect_hls_0_ctagf3yp/LabelSelect_hls_0.v:769:23: Operator ASSIGN expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                  : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45
#   769 |             ap_NS_fsm = 'bx;
#       |                       ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_LabelSelect_hls_0_ctagf3yp/LabelSelect_hls_0.v:790:35: Operator ASSIGNW expects 8 bits on the Assign RHS, but Assign RHS's VARREF 'ap_sig_allocacmp_block_1' generates 4 bits.
#                                                                                                  : ... In instance LabelSelect_hls_0.grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45
#   790 | assign conv2_i_i_i_cast_fu_109_p1 = ap_sig_allocacmp_block_1;
#       |                                   ^
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_LabelSelect_hls_0_ctagf3yp/LabelSelect_hls_0.v:355:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                   : ... In instance LabelSelect_hls_0
#   355 | #0 ap_CS_fsm = 5'd1;
#       |  ^
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_LabelSelect_hls_0_ctagf3yp/LabelSelect_hls_0.v:356:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                                   : ... In instance LabelSelect_hls_0
#   356 | #0 grp_LabelSelect_hls_0_Pipeline_VITIS_LOOP_488_3_fu_45_ap_start_reg = 1'b0;
#       |  ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_LabelSelect_hls_0_ctagf3yp/LabelSelect_hls_0.v:503:23: Operator ASSIGN expects 5 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                  : ... In instance LabelSelect_hls_0
#   503 |             ap_NS_fsm = 'bx;
#       |                       ^
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:355:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                     : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30.flow_control_loop_pipe_sequential_init_U
#   355 | #0 ap_loop_init_int = 1'b1;
#       |  ^
#                   ... For warning description see https://verilator.org/warn/STMTDLY?v=4.224
#                   ... Use "/* verilator lint_off STMTDLY */" and lint_on around source to disable this message.
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:356:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                     : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30.flow_control_loop_pipe_sequential_init_U
#   356 | #0 ap_done_cache = 1'b0;
#       |  ^
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:1036:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                      : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1036 | #0 ap_CS_iter0_fsm = 1'd1;
#       |  ^
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:1037:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                      : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1037 | #0 ap_CS_iter1_fsm = 2'd1;
#       |  ^
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:1038:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                      : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1038 | #0 ap_done_reg = 1'b0;
#       |  ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:1280:29: Operator ASSIGN expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                     : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1280 |             ap_NS_iter0_fsm = 'bx;
#       |                             ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:1304:29: Operator ASSIGN expects 2 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                     : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  1304 |             ap_NS_iter1_fsm = 'bx;
#       |                             ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:2027:30: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_13_fu_753_p2' generates 1 bits.
#                                                                                     : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2027 | assign zext_ln68_1_fu_759_p1 = r_13_fu_753_p2;
#       |                              ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:2029:30: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_21_fu_993_p2' generates 1 bits.
#                                                                                     : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2029 | assign zext_ln68_2_fu_999_p1 = r_21_fu_993_p2;
#       |                              ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:2031:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_29_fu_1233_p2' generates 1 bits.
#                                                                                     : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2031 | assign zext_ln68_3_fu_1239_p1 = r_29_fu_1233_p2;
#       |                               ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:2033:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_37_fu_1473_p2' generates 1 bits.
#                                                                                     : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2033 | assign zext_ln68_4_fu_1479_p1 = r_37_fu_1473_p2;
#       |                               ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:2035:31: Operator ASSIGNW expects 32 bits on the Assign RHS, but Assign RHS's VARREF 'r_45_fu_1713_p2' generates 1 bits.
#                                                                                     : ... In instance MVAU_hls_3.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
#  2035 | assign zext_ln68_5_fu_1719_p1 = r_45_fu_1713_p2;
#       |                               ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_3_10tvdqvv/MVAU_hls_3.v:
32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_90_fu_4889_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15874 | assign zext_ln90_90_fu_4895_p1 = r_90_fu_4889_p2;
#       |                                ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15876:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_91_fu_4905_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15876 | assign zext_ln90_91_fu_4911_p1 = r_91_fu_4905_p2;
#       |                                ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15878:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_92_fu_4921_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15878 | assign zext_ln90_92_fu_4927_p1 = r_92_fu_4921_p2;
#       |                                ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15880:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_93_fu_4937_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15880 | assign zext_ln90_93_fu_4943_p1 = r_93_fu_4937_p2;
#       |                                ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15882:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_94_fu_4953_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15882 | assign zext_ln90_94_fu_4959_p1 = r_94_fu_4953_p2;
#       |                                ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15884:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_95_fu_4969_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15884 | assign zext_ln90_95_fu_4975_p1 = r_95_fu_4969_p2;
#       |                                ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15886:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_96_fu_4985_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15886 | assign zext_ln90_96_fu_4991_p1 = r_96_fu_4985_p2;
#       |                                ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15888:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_97_fu_5001_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15888 | assign zext_ln90_97_fu_5007_p1 = r_97_fu_5001_p2;
#       |                                ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15890:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_98_fu_5595_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15890 | assign zext_ln90_98_fu_5601_p1 = r_98_fu_5595_p2;
#       |                                ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15892:32: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_99_fu_5611_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15892 | assign zext_ln90_99_fu_5617_p1 = r_99_fu_5611_p2;
#       |                                ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15894:31: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_9_fu_2703_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15894 | assign zext_ln90_9_fu_2709_p1 = r_9_fu_2703_p2;
#       |                               ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:15896:29: Operator ASSIGNW expects 2 bits on the Assign RHS, but Assign RHS's VARREF 'r_fu_2487_p2' generates 1 bits.
#                                                                                      : ... In instance MVAU_hls_0.grp_Matrix_Vector_Activate_Stream_Batch_fu_30
# 15896 | assign zext_ln90_fu_2493_p1 = r_fu_2487_p2;
#       |                             ^
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:345:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                     : ... In instance MVAU_hls_0
#   345 | #0 grp_Matrix_Vector_Activate_Stream_Batch_fu_30_ap_start_reg = 1'b0;
#       |  ^
# %Warning-STMTDLY: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:346:2: Unsupported: Ignoring delay on this delayed statement.
#                                                                                     : ... In instance MVAU_hls_0
#   346 | #0 ap_CS_fsm = 4'd1;
#       |  ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/rtlsim_MVAU_hls_0_8n_h2h0_/MVAU_hls_0.v:488:23: Operator ASSIGN expects 4 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                    : ... In instance MVAU_hls_0
#   488 |             ap_NS_fsm = 'bx;
#       |                       ^
# make: Entering directory '/tmp/finn_dev_pamela/pyverilator_MVAU_hls_2_3hjlwq_g'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /tmp/finn_dev_pamela/pyverilator_MVAU_hls_2_3hjlwq_g/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VMVAU_hls_2.cpp VMVAU_hls_2___024root__DepSet_h4cde490c__0.cpp VMVAU_hls_2__Trace__0.cpp VMVAU_hls_2__ConstPool_0.cpp VMVAU_hls_2___024root__Slow.cpp VMVAU_hls_2___024root__DepSet_h4cde490c__0__Slow.cpp VMVAU_hls_2__Syms.cpp VMVAU_hls_2__Trace__0__Slow.cpp > VMVAU_hls_2__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VMVAU_hls_2__ALL.o VMVAU_hls_2__ALL.cpp
# echo "" > VMVAU_hls_2__ALL.verilator_deplist.tmp
# Archive ar -rcs VMVAU_hls_2__ALL.a VMVAU_hls_2__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VMVAU_hls_2__ALL.a      -o VMVAU_hls_2
# rm VMVAU_hls_2__ALL.verilator_deplist.tmp
# make: Leaving directory '/tmp/finn_dev_pamela/pyverilator_MVAU_hls_2_3hjlwq_g'
# make: Entering directory '/tmp/finn_dev_pamela/pyverilator_Thresholding_hls_0_vekk_5kc'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /tmp/finn_dev_pamela/pyverilator_Thresholding_hls_0_vekk_5kc/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VThresholding_hls_0.cpp VThresholding_hls_0___024root__DepSet_hc3365717__0.cpp VThresholding_hls_0__Trace__0.cpp VThresholding_hls_0__ConstPool_0.cpp VThresholding_hls_0___024root__Slow.cpp VThresholding_hls_0___024root__DepSet_hc3365717__0__Slow.cpp VThresholding_hls_0__Syms.cpp VThresholding_hls_0__Trace__0__Slow.cpp > VThresholding_hls_0__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VThresholding_hls_0__ALL.o VThresholding_hls_0__ALL.cpp
# echo "" > VThresholding_hls_0__ALL.verilator_deplist.tmp
# Archive ar -rcs VThresholding_hls_0__ALL.a VThresholding_hls_0__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VThresholding_hls_0__ALL.a      -o VThresholding_hls_0
# rm VThresholding_hls_0__ALL.verilator_deplist.tmp
# make: Leaving directory '/tmp/finn_dev_pamela/pyverilator_Thresholding_hls_0_vekk_5kc'
# make: Entering directory '/tmp/finn_dev_pamela/pyverilator_MVAU_hls_0_sytja8b4'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /tmp/finn_dev_pamela/pyverilator_MVAU_hls_0_sytja8b4/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VMVAU_hls_0.cpp VMVAU_hls_0___024root__DepSet_h7dc701cd__0.cpp VMVAU_hls_0__Trace__0.cpp VMVAU_hls_0__ConstPool_0.cpp VMVAU_hls_0___024root__Slow.cpp VMVAU_hls_0___024root__DepSet_h7dc701cd__0__Slow.cpp VMVAU_hls_0__Syms.cpp VMVAU_hls_0__Trace__0__Slow.cpp > VMVAU_hls_0__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VMVAU_hls_0__ALL.o VMVAU_hls_0__ALL.cpp
# echo "" > VMVAU_hls_0__ALL.verilator_deplist.tmp
# Archive ar -rcs VMVAU_hls_0__ALL.a VMVAU_hls_0__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VMVAU_hls_0__ALL.a      -o VMVAU_hls_0
# rm VMVAU_hls_0__ALL.verilator_deplist.tmp
# make: Leaving directory '/tmp/finn_dev_pamela/pyverilator_MVAU_hls_0_sytja8b4'

# %% [markdown]
# The next step is to load the parent model and set the node attribute `model` in the StreamingDataflowPartition node (`sdp_node`). Afterwards the `exec_mode` is set in the parent model in each node and the model can be executed.

# %%
# parent model
model_for_rtlsim = ModelWrapper(build_dir + "/tfc_w1_a1_dataflow_parent.onnx")
# reference child model
sdp_node = getCustomOp(model_for_rtlsim.graph.node[1])
sdp_node.set_nodeattr("model", build_dir + "/tfc_w1_a1_dataflow_child.onnx")

model_for_rtlsim = model_for_rtlsim.transform(SetExecMode("rtlsim"))

# %%
output_dict = oxe.execute_onnx(model_for_rtlsim, input_dict)
output_rtlsim = output_dict[list(output_dict.keys())[0]]

try:
    assert np.isclose(output_rtlsim, np.where(output_golden[0]==np.amax(output_golden[0])), atol=1e-3).all()
    print("Results are the same!")
except AssertionError:
    assert False, "The results are not the same!"
# Out:
# Results are the same!

# %% [markdown]
# ### Emulation of stitched IP
#
# Here we use the same procedure. First the child model is loaded, but in contrast to the layer-by-layer emulation, the metadata property `exec_mode` is set to "rtlsim" for the whole child model. When the model is integrated and executed in the last step, the verilog files of the stitched IP of the child model are used.

# %%
from finn.transformation.fpgadataflow.insert_dwc import InsertDWC
from finn.transformation.fpgadataflow.insert_fifo import InsertFIFO
from finn.transformation.fpgadataflow.specialize_layers import SpecializeLayers
from finn.transformation.fpgadataflow.create_stitched_ip import CreateStitchedIP

child_model = ModelWrapper(build_dir + "/tfc_w1_a1_dataflow_child.onnx")
child_model = child_model.transform(InsertDWC())  
child_model = child_model.transform(InsertFIFO(create_shallow_fifos=True))
# DWC and FIFOs need to be specialized to either HLS or RTL variants
child_model = child_model.transform(SpecializeLayers(test_fpga_part))
child_model.save(build_dir + "/test.onnx");
child_model = child_model.transform(GiveUniqueNodeNames())
child_model = child_model.transform(PrepareIP(test_fpga_part, target_clk_ns))
child_model = child_model.transform(HLSSynthIP())
child_model = child_model.transform(CreateStitchedIP(test_fpga_part, target_clk_ns))
child_model = child_model.transform(PrepareRTLSim())
child_model.set_metadata_prop("exec_mode","rtlsim")
child_model.save(build_dir + "/tfc_w1_a1_dataflow_child.onnx");
# Out:
# /home/pamela/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for Thresholding_hls_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for MVAU_hls_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for MVAU_hls_1
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for MVAU_hls_2
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for MVAU_hls_3
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/prepare_ip.py:56: UserWarning: Using pre-existing code for LabelSelect_hls_0
#   warnings.warn("Using pre-existing code for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for LabelSelect_hls_0
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for MVAU_hls_3
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for MVAU_hls_2
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for MVAU_hls_1
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for MVAU_hls_0
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# /home/pamela/finn/src/finn/transformation/fpgadataflow/hlssynth_ip.py:74: UserWarning: Using pre-existing IP for Thresholding_hls_0
#   warnings.warn("Using pre-existing IP for %s" % node.name)
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingDataWidthConverter_rtl_1_m2dif08t/dwc.sv:106:4: Logical operator IF expects 1 bit on the If, but If's MODDIV generates 32 bits.
#                                                                                                            : ... In instance StreamingDataWidthConverter_rtl_1.impl.core
#   106 |    if(IBITS % OBITS) begin
#       |    ^~
#                 ... For warning description see https://verilator.org/warn/WIDTH?v=4.224
#                 ... Use "/* verilator lint_off WIDTH */" and lint_on around source to disable this message.
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingDataWidthConverter_rtl_1_m2dif08t/dwc.sv:135:11: Operator ASSIGN expects 5 bits on the Assign RHS, but Assign RHS's COND generates 32 bits.
#                                                                                                             : ... In instance StreamingDataWidthConverter_rtl_1.impl.core
#   135 |      acnt = ivld? -K+1 : 1;
#       |           ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingDataWidthConverter_rtl_1_m2dif08t/dwc.sv:141:18: Operator ADD expects 5 bits on the RHS, but RHS's VARREF 'ainc' generates 1 bits.
#                                                                                                             : ... In instance StreamingDataWidthConverter_rtl_1.impl.core
#   141 |     ACnt <= acnt + ainc;
#       |                  ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:122:54: Operator EQ expects 32 or 2 bits on the LHS, but LHS's VARREF 'addr_' generates 1 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_7.impl
#   122 |    assign addr_full_ = (state_==state_more) && (addr_==depth-2);
#       |                                                      ^~
#                 ... For warning description see https://verilator.org/warn/WIDTH?v=4.224
#                 ... Use "/* verilator lint_off WIDTH */" and lint_on around source to disable this message.
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:179:10: Operator ASSIGN expects 1 bits on the Assign RHS, but Assign RHS's SUB generates 32 or 2 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_7.impl
#   179 |   for (a_=depth-2; a_>0; a_=a_-1) begin
#       |          ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:190:21: Operator ASSIGNDLY expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_7.impl
#   190 |         addr_       <=  'bx;
#       |                     ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:299:16: Operator ASSIGNDLY expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_7.impl
#   299 |    addr_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:187:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   187 |         srlo_       <=  'bx;
#       |                     ^~
#                   *** See https://verilator.org/warn/COMBDLY before disabling this,
#                   else you may end up with different sim results.
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:188:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   188 |         shift_en_o_ <= 1'bx;
#       |                     ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:189:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   189 |         shift_en_   <= 1'bx;
#       |                     ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:190:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   190 |         addr_       <=  'bx;
#       |                     ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:191:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   191 |         state_      <= 2'bx;
#       |                     ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:196:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   196 |    srlo_       <= i_d;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:197:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   197 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:198:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   198 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:199:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   199 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:200:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   200 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:203:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   203 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:204:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   204 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:205:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   205 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:206:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   206 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:207:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   207 |    state_      <= state_empty;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:213:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   213 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:214:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   214 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:215:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   215 |    shift_en_   <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:216:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   216 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:217:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   217 |    state_      <= state_more;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:220:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   220 |    srlo_       <= i_d;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:221:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   221 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:222:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   222 |    shift_en_   <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:223:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   223 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:224:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   224 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:227:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   227 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:228:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   228 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:229:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   229 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:230:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   230 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:231:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   231 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:234:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   234 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:235:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   235 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:236:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   236 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:237:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   237 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:238:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   238 |    state_      <= state_empty;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:247:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   247 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:248:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   248 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:249:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   249 |    shift_en_   <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:250:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   250 |    addr_       <= addr;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:251:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   251 |    state_      <= state_more;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:254:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   254 |    srlo_       <= srl[addr];
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:255:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   255 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:256:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   256 |    shift_en_   <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:259:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   259 |    addr_       <= addr_zero_ ? 0         : addr-1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:260:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   260 |    state_      <= addr_zero_ ? state_one : state_more;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:296:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   296 |    srlo_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:297:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   297 |    shift_en_o_ <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:298:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   298 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:299:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   299 |    addr_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_7_6hnzclyw/Q_srl.v:300:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   300 |    state_      <= 2'bx;
#       |                ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:122:54: Operator EQ expects 32 or 2 bits on the LHS, but LHS's VARREF 'addr_' generates 1 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   122 |    assign addr_full_ = (state_==state_more) && (addr_==depth-2);
#       |                                                      ^~
#                 ... For warning description see https://verilator.org/warn/WIDTH?v=4.224
#                 ... Use "/* verilator lint_off WIDTH */" and lint_on around source to disable this message.
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:179:10: Operator ASSIGN expects 1 bits on the Assign RHS, but Assign RHS's SUB generates 32 or 2 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   179 |   for (a_=depth-2; a_>0; a_=a_-1) begin
#       |          ^
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:187:21: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   187 |         srlo_       <=  'bx;
#       |                     ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:190:21: Operator ASSIGNDLY expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   190 |         addr_       <=  'bx;
#       |                     ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:203:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   203 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:213:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   213 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:227:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   227 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:234:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   234 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:247:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   247 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:265:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   265 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:279:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   279 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:296:16: Operator ASSIGNDLY expects 8 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   296 |    srlo_       <=  'bx;
#       |                ^~
# %Warning-WIDTH: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:299:16: Operator ASSIGNDLY expects 1 bits on the Assign RHS, but Assign RHS's CONST '?32?bxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx' generates 32 bits.
#                                                                                                : ... In instance StreamingFIFO_rtl_8.impl
#   299 |    addr_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:187:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   187 |         srlo_       <=  'bx;
#       |                     ^~
#                   *** See https://verilator.org/warn/COMBDLY before disabling this,
#                   else you may end up with different sim results.
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:188:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   188 |         shift_en_o_ <= 1'bx;
#       |                     ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:189:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   189 |         shift_en_   <= 1'bx;
#       |                     ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:190:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   190 |         addr_       <=  'bx;
#       |                     ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:191:21: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   191 |         state_      <= 2'bx;
#       |                     ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:196:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   196 |    srlo_       <= i_d;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:197:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   197 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:198:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   198 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:199:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   199 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:200:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   200 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:203:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   203 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:204:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   204 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:205:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   205 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:206:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   206 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:207:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   207 |    state_      <= state_empty;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:213:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   213 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:214:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   214 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:215:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   215 |    shift_en_   <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:216:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   216 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:217:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   217 |    state_      <= state_more;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:220:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   220 |    srlo_       <= i_d;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:221:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   221 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:222:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   222 |    shift_en_   <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:223:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   223 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:224:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   224 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:227:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   227 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:228:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   228 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:229:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   229 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:230:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   230 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:231:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   231 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:234:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   234 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:235:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   235 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:236:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   236 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:237:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   237 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:238:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   238 |    state_      <= state_empty;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:247:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   247 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:248:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   248 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:249:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   249 |    shift_en_   <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:250:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   250 |    addr_       <= addr;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:251:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   251 |    state_      <= state_more;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:254:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   254 |    srlo_       <= srl[addr];
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:255:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   255 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:256:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   256 |    shift_en_   <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:259:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   259 |    addr_       <= addr_zero_ ? 0         : addr-1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:260:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   260 |    state_      <= addr_zero_ ? state_one : state_more;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:296:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   296 |    srlo_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_8_xace88d1/Q_srl.v:297:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   297 |    shift_en_o_ <= 1'bx;
#       |                ^~
# ...
#   231 |    state_      <= state_one;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:234:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   234 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:235:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   235 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:236:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   236 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:237:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   237 |    addr_       <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:238:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   238 |    state_      <= state_empty;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:247:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   247 |    srlo_       <= 'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:248:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   248 |    shift_en_o_ <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:249:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   249 |    shift_en_   <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:250:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   250 |    addr_       <= addr;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:251:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   251 |    state_      <= state_more;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:254:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   254 |    srlo_       <= srl[addr];
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:255:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   255 |    shift_en_o_ <= 1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:256:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   256 |    shift_en_   <= 0;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:259:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   259 |    addr_       <= addr_zero_ ? 0         : addr-1;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:260:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   260 |    state_      <= addr_zero_ ? state_one : state_more;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:296:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   296 |    srlo_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:297:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   297 |    shift_en_o_ <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:298:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   298 |    shift_en_   <= 1'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:299:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   299 |    addr_       <=  'bx;
#       |                ^~
# %Warning-COMBDLY: /tmp/finn_dev_pamela/code_gen_ipgen_StreamingFIFO_rtl_0_7uewuypi/Q_srl.v:300:16: Non-blocking assignment '<=' in combinational logic process
#                                                                                                  : ... This will be executed as a blocking assignment '='!
#   300 |    state_      <= 2'bx;
#       |                ^~
# make: Entering directory '/tmp/finn_dev_pamela/pyverilator_Thresholding_hls_0_uda79srx'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /tmp/finn_dev_pamela/pyverilator_Thresholding_hls_0_uda79srx/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VThresholding_hls_0.cpp VThresholding_hls_0___024root__DepSet_hc3365717__0.cpp VThresholding_hls_0__Trace__0.cpp VThresholding_hls_0__ConstPool_0.cpp VThresholding_hls_0___024root__Slow.cpp VThresholding_hls_0___024root__DepSet_hc3365717__0__Slow.cpp VThresholding_hls_0__Syms.cpp VThresholding_hls_0__Trace__0__Slow.cpp > VThresholding_hls_0__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VThresholding_hls_0__ALL.o VThresholding_hls_0__ALL.cpp
# echo "" > VThresholding_hls_0__ALL.verilator_deplist.tmp
# Archive ar -rcs VThresholding_hls_0__ALL.a VThresholding_hls_0__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VThresholding_hls_0__ALL.a      -o VThresholding_hls_0
# rm VThresholding_hls_0__ALL.verilator_deplist.tmp
# make: Leaving directory '/tmp/finn_dev_pamela/pyverilator_Thresholding_hls_0_uda79srx'
# make: Entering directory '/tmp/finn_dev_pamela/pyverilator_StreamingFIFO_rtl_1_gm667cr4'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /tmp/finn_dev_pamela/pyverilator_StreamingFIFO_rtl_1_gm667cr4/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VStreamingFIFO_rtl_1.cpp VStreamingFIFO_rtl_1___024root__DepSet_h617ba1de__0.cpp VStreamingFIFO_rtl_1__Trace__0.cpp VStreamingFIFO_rtl_1___024root__Slow.cpp VStreamingFIFO_rtl_1___024root__DepSet_h617ba1de__0__Slow.cpp VStreamingFIFO_rtl_1__Syms.cpp VStreamingFIFO_rtl_1__Trace__0__Slow.cpp > VStreamingFIFO_rtl_1__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VStreamingFIFO_rtl_1__ALL.o VStreamingFIFO_rtl_1__ALL.cpp
# echo "" > VStreamingFIFO_rtl_1__ALL.verilator_deplist.tmp
# Archive ar -rcs VStreamingFIFO_rtl_1__ALL.a VStreamingFIFO_rtl_1__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VStreamingFIFO_rtl_1__ALL.a      -o VStreamingFIFO_rtl_1
# rm VStreamingFIFO_rtl_1__ALL.verilator_deplist.tmp
# make: Leaving directory '/tmp/finn_dev_pamela/pyverilator_StreamingFIFO_rtl_1_gm667cr4'
# make: Entering directory '/tmp/finn_dev_pamela/pyverilator_StreamingFIFO_rtl_0_zq5n8zy2'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /tmp/finn_dev_pamela/pyverilator_StreamingFIFO_rtl_0_zq5n8zy2/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# /usr/bin/perl /usr/local/share/verilator/bin/verilator_includer -DVL_INCLUDE_OPT=include VStreamingFIFO_rtl_0.cpp VStreamingFIFO_rtl_0___024root__DepSet_hb5df65a9__0.cpp VStreamingFIFO_rtl_0__Trace__0.cpp VStreamingFIFO_rtl_0__ConstPool_0.cpp VStreamingFIFO_rtl_0___024root__Slow.cpp VStreamingFIFO_rtl_0___024root__DepSet_hb5df65a9__0__Slow.cpp VStreamingFIFO_rtl_0__Syms.cpp VStreamingFIFO_rtl_0__Trace__0__Slow.cpp > VStreamingFIFO_rtl_0__ALL.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o VStreamingFIFO_rtl_0__ALL.o VStreamingFIFO_rtl_0__ALL.cpp
# echo "" > VStreamingFIFO_rtl_0__ALL.verilator_deplist.tmp
# Archive ar -rcs VStreamingFIFO_rtl_0__ALL.a VStreamingFIFO_rtl_0__ALL.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o VStreamingFIFO_rtl_0__ALL.a      -o VStreamingFIFO_rtl_0
# rm VStreamingFIFO_rtl_0__ALL.verilator_deplist.tmp
# make: Leaving directory '/tmp/finn_dev_pamela/pyverilator_StreamingFIFO_rtl_0_zq5n8zy2'

# %%
# parent model
model_for_rtlsim = ModelWrapper(build_dir + "/tfc_w1_a1_dataflow_parent.onnx")
# reference child model
sdp_node = getCustomOp(model_for_rtlsim.graph.node[1])
sdp_node.set_nodeattr("model", build_dir + "/tfc_w1_a1_dataflow_child.onnx")

# %%
output_dict = oxe.execute_onnx(model_for_rtlsim, input_dict)
output_rtlsim = output_dict[list(output_dict.keys())[0]]
# Out:
# %Warning-MODDUP: /tmp/finn_dev_pamela/vivado_stitch_proj_gsiwzzg_/finn_design_wrapper.v:9994:8: Duplicate declaration of module: 'dwc_axi'
#  9994 | module dwc_axi #(
#       |        ^~~~~~~
#                  /tmp/finn_dev_pamela/vivado_stitch_proj_gsiwzzg_/finn_design_wrapper.v:4119:8: ... Location of original declaration
#  4119 | module dwc_axi #(
#       |        ^~~~~~~
#                  ... For warning description see https://verilator.org/warn/MODDUP?v=4.224
#                  ... Use "/* verilator lint_off MODDUP */" and lint_on around source to disable this message.
# %Warning-MODDUP: /tmp/finn_dev_pamela/vivado_stitch_proj_gsiwzzg_/finn_design_wrapper.v:34732:8: Duplicate declaration of module: 'dwc'
# 34732 | module dwc #(
#       |        ^~~
#                  /tmp/finn_dev_pamela/vivado_stitch_proj_gsiwzzg_/finn_design_wrapper.v:13216:8: ... Location of original declaration
# 13216 | module dwc #(
#       |        ^~~
# %Warning-TIMESCALEMOD: /home/pamela/finn/finn-rtllib/swg/swg_pkg.sv:32:9: Timescale missing on this module as other modules have it (IEEE 1800-2017 3.14.2.3)
#    32 | package swg;
#       |         ^~~
#                        /tmp/finn_dev_pamela/vivado_stitch_proj_gsiwzzg_/finn_design_wrapper.v:10:8: ... Location of module with timescale
#    10 | module MVAU_hls_1_Matrix_Vector_Activate_Stream_Batch_p_ZL7threshs_2_ROM_AUTO_1R (
#       |        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# %Warning-UNPACKED: /tmp/finn_dev_pamela/vivado_stitch_proj_gsiwzzg_/finn_design_wrapper.v:14824:10: Unsupported: Unpacked struct/union
#                                                                                                   : ... In instance finn_design_wrapper.finn_design_i.Thresholding_hls_0.Thresholding_hls_0_wstrm.inst.core.mem
# 14824 |  typedef struct {
#       |          ^~~~~~
# make: Entering directory '/tmp/finn_dev_pamela/pyverilator_ipstitched_4afhofhs'
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o pyverilator_wrapper.o /tmp/finn_dev_pamela/pyverilator_ipstitched_4afhofhs/pyverilator_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated.o /usr/local/share/verilator/include/verilated.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o verilated_vcd_c.o /usr/local/share/verilator/include/verilated_vcd_c.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o Vfinn_design_wrapper.o Vfinn_design_wrapper.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__1.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__1.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17 -Os -c -o Vfinn_design_wrapper__Trace__0.o Vfinn_design_wrapper__Trace__0.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper__ConstPool_0.o Vfinn_design_wrapper__ConstPool_0.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper___024root__Slow.o Vfinn_design_wrapper___024root__Slow.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0__Slow.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0__Slow.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper__Syms.o Vfinn_design_wrapper__Syms.cpp
# ccache g++  -I.  -MMD -I/usr/local/share/verilator/include -I/usr/local/share/verilator/include/vltstd -DVM_COVERAGE=0 -DVM_SC=0 -DVM_TRACE=1 -DVM_TRACE_FST=0 -DVM_TRACE_VCD=1 -faligned-new -fcf-protection=none -Wno-bool-operation -Wno-sign-compare -Wno-uninitialized -Wno-unused-but-set-variable -Wno-unused-parameter -Wno-unused-variable -Wno-shadow     -fPIC --std=c++11  -std=gnu++17  -c -o Vfinn_design_wrapper__Trace__0__Slow.o Vfinn_design_wrapper__Trace__0__Slow.cpp
# echo "" > Vfinn_design_wrapper__ALL.verilator_deplist.tmp
# Archive ar -rcs Vfinn_design_wrapper__ALL.a Vfinn_design_wrapper.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__1.o Vfinn_design_wrapper__Trace__0.o Vfinn_design_wrapper__ConstPool_0.o Vfinn_design_wrapper___024root__Slow.o Vfinn_design_wrapper___024root__DepSet_h47b9eb99__0__Slow.o Vfinn_design_wrapper__Syms.o Vfinn_design_wrapper__Trace__0__Slow.o
# g++ -fPIC -shared pyverilator_wrapper.o verilated.o verilated_vcd_c.o Vfinn_design_wrapper__ALL.a      -o Vfinn_design_wrapper
# rm Vfinn_design_wrapper__ALL.verilator_deplist.tmp
# make: Leaving directory '/tmp/finn_dev_pamela/pyverilator_ipstitched_4afhofhs'

# %%
try:
    assert np.isclose(output_rtlsim, np.where(output_golden[0]==np.amax(output_golden[0])), atol=1e-3).all()
    print("Results are the same!")
except AssertionError:
    assert False, "The results are not the same!"
# Out:
# Results are the same!
